# %% [markdown]
# ## California Housing Price
# - predict median price per district
# - model: regression/labeled supervised learning
# - dataset: https://github.com/ageron/handson-ml2/tree/master/datasets/housing

# %% [markdown]
# ### 1. Read Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow import feature_column
from tensorflow.keras import layers

# %%
df=pd.read_csv("california_housing.csv")
df['median_house_value']/=1000
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252               452.6        NEAR BAY
# 1      2401.0      1138.0         8.3014               358.5        NEAR BAY
# 2       496.0       177.0         7.2574               352.1        NEAR BAY
# 3       558.0       219.0         5.6431               341.3        NEAR BAY
# 4       565.0       259.0         3.8462               342.2        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.isna().sum()
#total_badrooms 207/20640 is missing
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df=df.dropna()
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# ### 2. Data Exploration

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean           206.864413
# std            115.435667
# min             14.999000
# 25%            119.500000
# 50%            179.700000
# 75%            264.700000
# max            500.001000

# %% [markdown]
# #### Take away:
# - comparing to 75%, max for `total_rooms`, `population`, `households` need a further check.
# - abnormal data for target col `median_house_value`.

# %%
df=df[(df.total_rooms<=5000)&(df.total_bedrooms<=1000)&(df.population<=2500)&(df.households<=1000)&
      (df.median_income<=8)&(df.median_house_value<500)]

#df.median_house_value.hist(bins=100)
#df.total_bedrooms.hist(bins=100)
#df.median_income.hist(bins=100)
#df.total_rooms.hist(bins=100)
#df.population.hist(bins=100)
#df.households.hist(bins=100)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaled_df=scaler.fit_transform(df.loc[:,df.columns!='ocean_proximity']) 
scaled_df=pd.DataFrame(scaled_df,columns=df.columns.values[0:-1])
scaled_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.304883  0.979618            1.812895    -0.581462       -1.176249
# 1  -1.309868  0.979618            1.812895    -0.778082       -0.946837
# 2  -1.309868  0.979618            1.812895    -0.418462       -0.717426
# 3  -1.309868  0.979618            1.812895    -1.139739       -1.058994
# 4  -1.309868  0.975021            1.812895     0.506566        0.348063
#
#    population  households  median_income  median_house_value
# 0   -1.202281   -1.189649       2.533741            1.723464
# 1   -1.083693   -0.959439       1.420463            1.610331
# 2   -1.070304   -0.740191       0.181256            1.619758
# 3   -1.361037   -1.101950       0.312701            0.860301
# 4   -0.058477    0.657516       0.052225            1.169321

# %%
scaled_df.hist(bins=100,figsize=(15,10))
plt.show()

# %% [markdown]
# ### 3. Feature Engineering

# %%
feature_columns = []

# %%
#location
resolution_in_degrees = 0.4 

latitude_num = tf.feature_column.numeric_column("latitude")
latitude_bins = list(np.arange(int(min(scaled_df['latitude'])), int(max(scaled_df['latitude'])), resolution_in_degrees))
latitude = tf.feature_column.bucketized_column(latitude_num, latitude_bins)

longitude_num = tf.feature_column.numeric_column("longitude")
longitude_bins = list(np.arange(int(min(scaled_df['longitude'])), int(max(scaled_df['longitude'])), resolution_in_degrees))
longitude = tf.feature_column.bucketized_column(longitude_num, longitude_bins)

lat_x_lon = tf.feature_column.crossed_column([latitude, longitude], hash_bucket_size=100)
crossed_feature = tf.feature_column.indicator_column(lat_x_lon)
feature_columns.append(crossed_feature)

ocean_proximity= feature_column.indicator_column("ocean_proximity")
feature_columns.append(ocean_proximity)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-9faeb94097a6> in <module>
#      14 feature_columns.append(crossed_feature)
#      15
# ---> 16 ocean_proximity= feature_column.indicator_column("ocean_proximity")
#      17 feature_columns.append(ocean_proximity)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/feature_column/feature_column_v2.py in indicator_column(categorical_column)
#    1616   if not isinstance(categorical_column,
#    1617                     (CategoricalColumn, fc_old._CategoricalColumn)):  # pylint: disable=protected-access
# -> 1618     raise ValueError(
#    1619         'Unsupported input type. Input must be a CategoricalColumn. '
#    1620         'Given: {}'.format(categorical_column))
#
# ValueError: Unsupported input type. Input must be a CategoricalColumn. Given: ocean_proximity

# %%
#demographic
med_income = tf.feature_column.numeric_column("median_income")
feature_columns.append(med_income)

population = tf.feature_column.numeric_column("population")
feature_columns.append(population)

households = tf.feature_column.numeric_column("households")
feature_columns.append(households)

# %%
#house
house_age=tf.feature_column.numeric_column("housing_median_age")
feature_columns.append(house_age)

ttl_room=tf.feature_column.numeric_column("total_rooms")
feature_columns.append(ttl_room)

ttl_bedroom=tf.feature_column.numeric_column("total_bedrooms")
feature_columns.append(ttl_bedroom)

# %%
feature_layer = layers.DenseFeatures(feature_columns)

# %% [markdown]
# ### Train/Test Split

# %%
from sklearn.model_selection import train_test_split
train_df, test_df= train_test_split(scaled_df,test_size=0.22, random_state=123)
print("Total df size: %i\n train_df size: %i \n test_df size: %i"\
%(df.shape[0],train_df.shape[0],test_df.shape[0]))
# Out:
# Total df size: 16573
#  train_df size: 12926
#  test_df size: 3647

# %% [markdown]
# ### 4. Modeling

# %% [markdown]
# ### 4.1 Define functions that build and train a model
# - build_model(learning_rate), which builds a randomly-initialized model.
# - train_model(model, feature, label, epochs), which trains the model from the examples (feature and label) you pass.

# %%
#Define the functions that build and train a model
def build_model(my_learning_rate, feature_layer):
  # Create and compile a simple linear regression model.
  model = tf.keras.models.Sequential() # Most simple tf.keras models are sequential.

  # Describe the topography of the model.
  model.add(feature_layer)
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,))) #a single node in a single layer.

  # Compile into TensorFlow. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        

#Train the model by feeding feature and label.
def train_model(model, df, epochs, batch_size, label_name):
    
  features = {name:np.array(value) for name, value in df.items()}
  label = np.array(features.pop(label_name))
    
  history = model.fit(x=features,y=label,
                      batch_size=batch_size,epochs=epochs,
                      shuffle=True) # specified number of epochs. 

  # Gather the trained model's weight and bias.
  #trained_weight = model.get_weights()[0]
  #trained_bias = model.get_weights()[1]

  epochs = history.epoch # The list of epochs is stored separately from the rest of history.
  
  hist = pd.DataFrame(history.history) # Isolate the error for each epoch.
  rmse = hist["root_mean_squared_error"] # Take a snapshot of the model's root mean squared error at each epoch. 

  return epochs, rmse

# %% [markdown]
# ### 4.2 Define plotting functions
# - a loss curve

# %%
#Plot a curve of loss vs. epoch.
def plot_the_loss_curve(epochs, rmse):
  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.94, rmse.max()* 1.05])
  plt.show()

# %% [markdown]
# ### 4.3 Call the model functions

# %%
# Hyperparameters:
learning_rate = 0.05
epochs = 200
batch_size = 100

label_name="median_house_value" 

# Invoke the functions.
my_model = build_model(learning_rate,feature_layer)
epochs, rmse = train_model(my_model, train_df, 
                           epochs, batch_size, label_name)

plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'longitude': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=float32>, 'latitude': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=float32>, 'housing_median_age': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=float32>, 'total_rooms': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=float32>, 'total_bedrooms': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=float32>, 'population': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float32>, 'households': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float32>, 'median_income': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=float32>}
# Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'longitude': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=float32>, 'latitude': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=float32>, 'housing_median_age': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=float32>, 'total_rooms': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=float32>, 'total_bedrooms': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=float32>, 'population': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float32>, 'households': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float32>, 'median_income': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=float32>}
# Consider rewriting this model with the Functional API.
# 130/130 [==============================] - 1s 2ms/step - loss: 0.4884 - root_mean_squared_error: 0.6930
# Epoch 2/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3652 - root_mean_squared_error: 0.6042
# Epoch 3/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3763 - root_mean_squared_error: 0.6133
# Epoch 4/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3874 - root_mean_squared_error: 0.6223
# Epoch 5/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3750 - root_mean_squared_error: 0.6123
# Epoch 6/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3695 - root_mean_squared_error: 0.6078
# Epoch 7/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3850 - root_mean_squared_error: 0.6204
# Epoch 8/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3742 - root_mean_squared_error: 0.6117
# Epoch 9/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3798 - root_mean_squared_error: 0.6163
# Epoch 10/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3805 - root_mean_squared_error: 0.6167
# Epoch 11/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3738 - root_mean_squared_error: 0.6114
# Epoch 12/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3664 - root_mean_squared_error: 0.6052
# Epoch 13/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175
# Epoch 14/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3746 - root_mean_squared_error: 0.6120
# Epoch 15/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3740 - root_mean_squared_error: 0.6113
# Epoch 16/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3902 - root_mean_squared_error: 0.6245
# Epoch 17/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3756 - root_mean_squared_error: 0.6129
# Epoch 18/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3740 - root_mean_squared_error: 0.6115
# Epoch 19/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3685 - root_mean_squared_error: 0.6070
# Epoch 20/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3738 - root_mean_squared_error: 0.6112
# Epoch 21/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3749 - root_mean_squared_error: 0.6122
# Epoch 22/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3753 - root_mean_squared_error: 0.6124
# Epoch 23/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3759 - root_mean_squared_error: 0.6130
# Epoch 24/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3623 - root_mean_squared_error: 0.6018
# Epoch 25/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3804 - root_mean_squared_error: 0.6167
# Epoch 26/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3836 - root_mean_squared_error: 0.6193
# Epoch 27/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3719 - root_mean_squared_error: 0.6098
# Epoch 28/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3805 - root_mean_squared_error: 0.6168
# Epoch 29/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3781 - root_mean_squared_error: 0.6148
# Epoch 30/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3647 - root_mean_squared_error: 0.6038
# Epoch 31/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3749 - root_mean_squared_error: 0.6120
# Epoch 32/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3753 - root_mean_squared_error: 0.6125
# Epoch 33/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3628 - root_mean_squared_error: 0.6022
# Epoch 34/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3879 - root_mean_squared_error: 0.6225
# Epoch 35/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3675 - root_mean_squared_error: 0.6062
# Epoch 36/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3883 - root_mean_squared_error: 0.6231
# Epoch 37/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3693 - root_mean_squared_error: 0.6076
# Epoch 38/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3805 - root_mean_squared_error: 0.6168
# Epoch 39/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3774 - root_mean_squared_error: 0.6142
# Epoch 40/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3686 - root_mean_squared_error: 0.6069
# Epoch 41/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3822 - root_mean_squared_error: 0.6180
# Epoch 42/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3821 - root_mean_squared_error: 0.6181
# Epoch 43/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3764 - root_mean_squared_error: 0.6135
# Epoch 44/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3816 - root_mean_squared_error: 0.6177
# Epoch 45/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3654 - root_mean_squared_error: 0.6043
# Epoch 46/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3639 - root_mean_squared_error: 0.6032
# Epoch 47/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3796 - root_mean_squared_error: 0.6160
# Epoch 48/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3737 - root_mean_squared_error: 0.6112
# Epoch 49/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3757 - root_mean_squared_error: 0.6129
# Epoch 50/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3680 - root_mean_squared_error: 0.6066
# Epoch 51/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3681 - root_mean_squared_error: 0.6066
# Epoch 52/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3826 - root_mean_squared_error: 0.6184
# Epoch 53/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3812 - root_mean_squared_error: 0.6173
# Epoch 54/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3690 - root_mean_squared_error: 0.6074
# Epoch 55/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3682 - root_mean_squared_error: 0.6067
# Epoch 56/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3658 - root_mean_squared_error: 0.6048
# Epoch 57/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3822 - root_mean_squared_error: 0.6182
# Epoch 58/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3639 - root_mean_squared_error: 0.6032
# Epoch 59/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3658 - root_mean_squared_error: 0.6048
# Epoch 60/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3755 - root_mean_squared_error: 0.6127
# Epoch 61/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3681 - root_mean_squared_error: 0.6066
# Epoch 62/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3764 - root_mean_squared_error: 0.6134
# Epoch 63/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3699 - root_mean_squared_error: 0.6081
# Epoch 64/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3666 - root_mean_squared_error: 0.6054
# Epoch 65/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3677 - root_mean_squared_error: 0.6063
# Epoch 66/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3831 - root_mean_squared_error: 0.6189
# Epoch 67/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3660 - root_mean_squared_error: 0.6049
# Epoch 68/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3755 - root_mean_squared_error: 0.6127
# Epoch 69/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3718 - root_mean_squared_error: 0.6097
# Epoch 70/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3712 - root_mean_squared_error: 0.6092
# Epoch 71/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3799 - root_mean_squared_error: 0.6163
# Epoch 72/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3785 - root_mean_squared_error: 0.6152
# Epoch 73/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3837 - root_mean_squared_error: 0.6194
# Epoch 74/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3864 - root_mean_squared_error: 0.6214
# Epoch 75/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3837 - root_mean_squared_error: 0.6193
# Epoch 76/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3711 - root_mean_squared_error: 0.6091
# Epoch 77/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3615 - root_mean_squared_error: 0.6011
# Epoch 78/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3627 - root_mean_squared_error: 0.6022
# Epoch 79/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3799 - root_mean_squared_error: 0.6163
# Epoch 80/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3772 - root_mean_squared_error: 0.6141
# Epoch 81/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3662 - root_mean_squared_error: 0.6051
# Epoch 82/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3710 - root_mean_squared_error: 0.6090
# Epoch 83/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3936 - root_mean_squared_error: 0.6265
# Epoch 84/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3660 - root_mean_squared_error: 0.6049
# Epoch 85/200
# 130/130 [==============================] - 1s 4ms/step - loss: 0.3728 - root_mean_squared_error: 0.6105
# Epoch 86/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3737 - root_mean_squared_error: 0.6113
# Epoch 87/200
# 130/130 [==============================] - 0s 4ms/step - loss: 0.3593 - root_mean_squared_error: 0.5993
# Epoch 88/200
# 130/130 [==============================] - 1s 7ms/step - loss: 0.3806 - root_mean_squared_error: 0.6168A: 0s - loss: 0.3839 - root_mean_squared_error: 0.6
# Epoch 89/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3762 - root_mean_squared_error: 0.6133
# Epoch 90/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3759 - root_mean_squared_error: 0.6130A: 0s - loss: 0.3764 - root_mean_squared_error: 0.6
# Epoch 91/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3792 - root_mean_squared_error: 0.6156
# Epoch 92/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3639 - root_mean_squared_error: 0.6031
# Epoch 93/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3650 - root_mean_squared_error: 0.6041
# Epoch 94/200
# 130/130 [==============================] - 1s 4ms/step - loss: 0.3629 - root_mean_squared_error: 0.6024
# Epoch 95/200
# 130/130 [==============================] - 0s 4ms/step - loss: 0.3812 - root_mean_squared_error: 0.6172
# Epoch 96/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3671 - root_mean_squared_error: 0.6058
# Epoch 97/200
# 130/130 [==============================] - 1s 4ms/step - loss: 0.3755 - root_mean_squared_error: 0.6128
# Epoch 98/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3792 - root_mean_squared_error: 0.6156
# Epoch 99/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3708 - root_mean_squared_error: 0.6088
# Epoch 100/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3823 - root_mean_squared_error: 0.6182
# Epoch 101/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3655 - root_mean_squared_error: 0.6045
# Epoch 102/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3662 - root_mean_squared_error: 0.6051
# Epoch 103/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3854 - root_mean_squared_error: 0.6208
# Epoch 104/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3754 - root_mean_squared_error: 0.6127
# Epoch 105/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3854 - root_mean_squared_error: 0.6206
# Epoch 106/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3702 - root_mean_squared_error: 0.6083
# Epoch 107/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3831 - root_mean_squared_error: 0.6187
# Epoch 108/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3739 - root_mean_squared_error: 0.6113
# Epoch 109/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3735 - root_mean_squared_error: 0.6111
# Epoch 110/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3767 - root_mean_squared_error: 0.6137
# Epoch 111/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3745 - root_mean_squared_error: 0.6119
# Epoch 112/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3753 - root_mean_squared_error: 0.6124
# Epoch 113/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3646 - root_mean_squared_error: 0.6037
# Epoch 114/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3588 - root_mean_squared_error: 0.5989
# Epoch 115/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3682 - root_mean_squared_error: 0.6067
# Epoch 116/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3749 - root_mean_squared_error: 0.6122
# Epoch 117/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3832 - root_mean_squared_error: 0.6190
# Epoch 118/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3684 - root_mean_squared_error: 0.6069
# Epoch 119/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3872 - root_mean_squared_error: 0.6221
# Epoch 120/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3743 - root_mean_squared_error: 0.6118
# Epoch 121/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3892 - root_mean_squared_error: 0.6234
# Epoch 122/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3741 - root_mean_squared_error: 0.6115
# Epoch 123/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3789 - root_mean_squared_error: 0.6154
# Epoch 124/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3691 - root_mean_squared_error: 0.6075
# Epoch 125/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3645 - root_mean_squared_error: 0.6037
# Epoch 126/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3817 - root_mean_squared_error: 0.6177
# Epoch 127/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3776 - root_mean_squared_error: 0.6145
# Epoch 128/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3693 - root_mean_squared_error: 0.6077
# Epoch 129/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3768 - root_mean_squared_error: 0.6138
# Epoch 130/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3751 - root_mean_squared_error: 0.6124
# Epoch 131/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3679 - root_mean_squared_error: 0.6064
# Epoch 132/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3719 - root_mean_squared_error: 0.6097
# Epoch 133/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3701 - root_mean_squared_error: 0.6082
# Epoch 134/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3716 - root_mean_squared_error: 0.6096
# Epoch 135/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3708 - root_mean_squared_error: 0.6089
# Epoch 136/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3736 - root_mean_squared_error: 0.6112
# Epoch 137/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3694 - root_mean_squared_error: 0.6078
# Epoch 138/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3816 - root_mean_squared_error: 0.6176
# Epoch 139/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3740 - root_mean_squared_error: 0.6114
# Epoch 140/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3755 - root_mean_squared_error: 0.6127
# Epoch 141/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3826 - root_mean_squared_error: 0.6184
# Epoch 142/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3732 - root_mean_squared_error: 0.6107
# Epoch 143/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3840 - root_mean_squared_error: 0.6196
# Epoch 144/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3676 - root_mean_squared_error: 0.6062
# Epoch 145/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3691 - root_mean_squared_error: 0.6074
# Epoch 146/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3735 - root_mean_squared_error: 0.6111
# Epoch 147/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3757 - root_mean_squared_error: 0.6129
# Epoch 148/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3826 - root_mean_squared_error: 0.6185
# Epoch 149/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3717 - root_mean_squared_error: 0.6096
# Epoch 150/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3732 - root_mean_squared_error: 0.6108
# Epoch 151/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3741 - root_mean_squared_error: 0.6116
# Epoch 152/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3767 - root_mean_squared_error: 0.6137
# Epoch 153/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3899 - root_mean_squared_error: 0.6236
# Epoch 154/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3642 - root_mean_squared_error: 0.6035
# Epoch 155/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3737 - root_mean_squared_error: 0.6112
# Epoch 156/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3796 - root_mean_squared_error: 0.6160
# Epoch 157/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3848 - root_mean_squared_error: 0.6203
# Epoch 158/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3724 - root_mean_squared_error: 0.6102
# Epoch 159/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3793 - root_mean_squared_error: 0.6159
# Epoch 160/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3710 - root_mean_squared_error: 0.6091
# Epoch 161/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3610 - root_mean_squared_error: 0.6008
# Epoch 162/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3713 - root_mean_squared_error: 0.6092
# Epoch 163/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3688 - root_mean_squared_error: 0.6071
# Epoch 164/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3796 - root_mean_squared_error: 0.6161
# Epoch 165/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3782 - root_mean_squared_error: 0.6150
# Epoch 166/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3793 - root_mean_squared_error: 0.6159
# Epoch 167/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3712 - root_mean_squared_error: 0.6092
# Epoch 168/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3663 - root_mean_squared_error: 0.6051
# Epoch 169/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3596 - root_mean_squared_error: 0.5996
# Epoch 170/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3703 - root_mean_squared_error: 0.6085
# Epoch 171/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3761 - root_mean_squared_error: 0.6133
# Epoch 172/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3735 - root_mean_squared_error: 0.6111
# Epoch 173/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3773 - root_mean_squared_error: 0.6141
# Epoch 174/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3673 - root_mean_squared_error: 0.6059
# Epoch 175/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3872 - root_mean_squared_error: 0.6219
# Epoch 176/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3868 - root_mean_squared_error: 0.6218
# Epoch 177/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3731 - root_mean_squared_error: 0.6108
# Epoch 178/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3856 - root_mean_squared_error: 0.6208
# Epoch 179/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3714 - root_mean_squared_error: 0.6094
# Epoch 180/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3667 - root_mean_squared_error: 0.6055
# Epoch 181/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3781 - root_mean_squared_error: 0.6148
# Epoch 182/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3722 - root_mean_squared_error: 0.6099
# Epoch 183/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3706 - root_mean_squared_error: 0.6087
# Epoch 184/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3590 - root_mean_squared_error: 0.5990
# Epoch 185/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3754 - root_mean_squared_error: 0.6126
# Epoch 186/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3741 - root_mean_squared_error: 0.6116
# Epoch 187/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3749 - root_mean_squared_error: 0.6123
# Epoch 188/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3719 - root_mean_squared_error: 0.6096
# Epoch 189/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3827 - root_mean_squared_error: 0.6186
# Epoch 190/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3735 - root_mean_squared_error: 0.6111
# Epoch 191/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3736 - root_mean_squared_error: 0.6112
# Epoch 192/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3803 - root_mean_squared_error: 0.6166
# Epoch 193/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3781 - root_mean_squared_error: 0.6149
# Epoch 194/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3780 - root_mean_squared_error: 0.6146
# Epoch 195/200
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3604 - root_mean_squared_error: 0.6003
# Epoch 196/200
# 130/130 [==============================] - 1s 4ms/step - loss: 0.3666 - root_mean_squared_error: 0.6053
# Epoch 197/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3838 - root_mean_squared_error: 0.6192
# Epoch 198/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3695 - root_mean_squared_error: 0.6078
# Epoch 199/200
# 130/130 [==============================] - 0s 2ms/step - loss: 0.3678 - root_mean_squared_error: 0.6064
# Epoch 200/200
# 130/130 [==============================] - 0s 1ms/step - loss: 0.3698 - root_mean_squared_error: 0.6081

# %%
print("\n: Evaluate the new model on the test set:")
test_features = {name:np.array(value) for name, value in test_df.items()}
test_label = np.array(test_features.pop(label_name))
my_model.evaluate(x=test_features, y=test_label, batch_size=batch_size)
# Out:
# : Evaluate the new model on the test set:
# 37/37 [==============================] - 0s 2ms/step - loss: 0.3628 - root_mean_squared_error: 0.6023
# [0.36276379227638245, 0.6022987365722656]
